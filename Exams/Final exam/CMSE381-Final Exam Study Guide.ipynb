# %% [markdown]
# <font color='red'>
# The exam is open-book. However, please try to memorize as much of the content as possible to help speed up the completion of the exam.
# </font>
#
# ## Topics to be covered in the Final Exam
#
#  - prediction vs inference
#  - regression vs classification
#  - overfitting
#  - error decomposition
#      - reducible vs irreducible error
#      - bias variance tradeoff
#  - measuring the error
#     - MSE, RSS, $R^2$
#
#  - Linear regression
#       - RSS
#       - closed form solution for simple linear regression
#       - hypothesis test
#       - confidence interval
#       - dummy variables for qualitative predictors
#       - interaction terms ($p\geq 2$)
#  - Logistic regression
#      - odds
#      - logistic function
#      - maximum likelihood fitting for $\beta_0$ and $\beta_1$
#      - confusion matrix
#      - Multinomial Logistic Regression
#  - LDA (p=1)
#      - Bayes theorem
#      - calculating the Bayes decision boundary
#      - QDA
#      - ROC, AUC
#  - CV
#      - LOOCV
#      - Leverage statistic
#      - k-fold CV
#      - bootstrap
#
#
#  - Subset selection
#      - best subset
#      - forward/backward subset selection
#
#  - Ridge and Lasso
#      -  mathematical formulae
#      -  geometric interpretations
#      - scale equivariant
#      - selecting the best tuning parameter
#
#  - Dimension reduction
#     - PCR (keystep is PCA)
#     - PLS (key is the use of residual)
#  - Basis function
#     - Polynomial and step functions
#     - basis functions
#     - Regression splines (cubic and its extention to any orders of splines)
#  - Decision trees
#    - equivalence between a 2-variable decision trees and the 2D region partition
#    - building decision trees based on data
#    - Random Forests
#  - SVC and SVM
#    - hyperplane and margin
#    - construction of MMC
#    - Gini index
#    - inner product representation of the hyperplane
#    - extension to kernels
#    - slack variables
#  - Neural Network
#     - NN architecture
#     - making predictions using NN
#     - training of NN)
#     - CNN (computing 1D or 2D convolution operations)
#
# In summary, you're expected to know how to
#   - manually train the machine learning methods (kNN, LDA, QDA,  subset selection, decision trees) using a given training dataset.
#   - manually set up the objective function for linear and logistic regression as well as Ridge and Lasso.
#   - manually compute predictions given a trained model from linear regression, logistic regression, Random Forests, Neural Network, Convolutional Neural network
#   - understand the high-level intuition of all the methods
#   - know how to do hyper-parameter tuning
#   - use python to apply all these methods  to a given dataset and interpret the results
